# %%
# %run main.py
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Desktop\AAAAAAAAAA\main.py in <module>
#     109
#     110 if __name__ == '__main__':
# --> 111     main()
#
# ~\Desktop\AAAAAAAAAA\main.py in main()
#     106                  (generations, population))
#     107
# --> 108     generate(generations, population, nn_param_choices, dataset)
#     109
#     110 if __name__ == '__main__':
#
# ~\Desktop\AAAAAAAAAA\main.py in generate(generations, population, nn_param_choices, dataset)
#      60
#      61         # Тренеруем и получаем точность для сетей
# ---> 62         train_networks(networks, dataset)
#      63
#      64         # Получаем среднюю точность для этого поколения.
#
# ~\Desktop\AAAAAAAAAA\main.py in train_networks(networks, dataset)
#      21     pbar = tqdm(total=len(networks))
#      22     for network in networks:
# ...

# %%
# %run main.py
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Desktop\AAAAAAAAAA\main.py in <module>
#     109
#     110 if __name__ == '__main__':
# --> 111     main()
#
# ~\Desktop\AAAAAAAAAA\main.py in main()
#     106                  (generations, population))
#     107
# --> 108     generate(generations, population, nn_param_choices, dataset)
#     109
#     110 if __name__ == '__main__':
#
# ~\Desktop\AAAAAAAAAA\main.py in generate(generations, population, nn_param_choices, dataset)
#      60
#      61         # Тренеруем и получаем точность для сетей
# ---> 62         train_networks(networks, dataset)
#      63
#      64         # Получаем среднюю точность для этого поколения.
#
# ~\Desktop\AAAAAAAAAA\main.py in train_networks(networks, dataset)
#      21     pbar = tqdm(total=len(networks))
#      22     for network in networks:
# ...

# %%
# %run main.py
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Desktop\AAAAAAAAAA\main.py in <module>
#     109
#     110 if __name__ == '__main__':
# --> 111     main()
#
# ~\Desktop\AAAAAAAAAA\main.py in main()
#     106                  (generations, population))
#     107
# --> 108     generate(generations, population, nn_param_choices, dataset)
#     109
#     110 if __name__ == '__main__':
#
# ~\Desktop\AAAAAAAAAA\main.py in generate(generations, population, nn_param_choices, dataset)
#      60
#      61         # Тренеруем и получаем точность для сетей
# ---> 62         train_networks(networks, dataset)
#      63
#      64         # Получаем среднюю точность для этого поколения.
#
# ~\Desktop\AAAAAAAAAA\main.py in train_networks(networks, dataset)
#      21     pbar = tqdm(total=len(networks))
#      22     for network in networks:
# ...

# %%
# %run main.py
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Desktop\AAAAAAAAAA\main.py in <module>
#     109
#     110 if __name__ == '__main__':
# --> 111     main()
#
# ~\Desktop\AAAAAAAAAA\main.py in main()
#     106                  (generations, population))
#     107
# --> 108     generate(generations, population, nn_param_choices, dataset)
#     109
#     110 if __name__ == '__main__':
#
# ~\Desktop\AAAAAAAAAA\main.py in generate(generations, population, nn_param_choices, dataset)
#      60
#      61         # Тренеруем и получаем точность для сетей
# ---> 62         train_networks(networks, dataset)
#      63
#      64         # Получаем среднюю точность для этого поколения.
#
# ~\Desktop\AAAAAAAAAA\main.py in train_networks(networks, dataset)
#      21     pbar = tqdm(total=len(networks))
#      22     for network in networks:
# ...

# %%
# %run main.py
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Desktop\AAAAAAAAAA\main.py in <module>
#     109
#     110 if __name__ == '__main__':
# --> 111     main()
#
# ~\Desktop\AAAAAAAAAA\main.py in main()
#     106                  (generations, population))
#     107
# --> 108     generate(generations, population, nn_param_choices, dataset)
#     109
#     110 if __name__ == '__main__':
#
# ~\Desktop\AAAAAAAAAA\main.py in generate(generations, population, nn_param_choices, dataset)
#      60
#      61         # Тренеруем и получаем точность для сетей
# ---> 62         train_networks(networks, dataset)
#      63
#      64         # Получаем среднюю точность для этого поколения.
#
# ~\Desktop\AAAAAAAAAA\main.py in train_networks(networks, dataset)
#      21     pbar = tqdm(total=len(networks))
#      22     for network in networks:
# ...

# %%
# %run main.py
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\Desktop\AAAAAAAAAA\main.py in <module>
#     109
#     110 if __name__ == '__main__':
# --> 111     main()
#
# ~\Desktop\AAAAAAAAAA\main.py in main()
#     106                  (generations, population))
#     107
# --> 108     generate(generations, population, nn_param_choices, dataset)
#     109
#     110 if __name__ == '__main__':
#
# ~\Desktop\AAAAAAAAAA\main.py in generate(generations, population, nn_param_choices, dataset)
#      60
#      61         # Тренеруем и получаем точность для сетей
# ---> 62         train_networks(networks, dataset)
#      63
#      64         # Получаем среднюю точность для этого поколения.
#
# ~\Desktop\AAAAAAAAAA\main.py in train_networks(networks, dataset)
#      21     pbar = tqdm(total=len(networks))
#      22     for network in networks:
# ...

# %%
# %run main.py
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\Desktop\AAAAAAAAAA\main.py in <module>
#     109
#     110 if __name__ == '__main__':
# --> 111     main()
#
# ~\Desktop\AAAAAAAAAA\main.py in main()
#     106                  (generations, population))
#     107
# --> 108     generate(generations, population, nn_param_choices, dataset)
#     109
#     110 if __name__ == '__main__':
#
# ~\Desktop\AAAAAAAAAA\main.py in generate(generations, population, nn_param_choices, dataset)
#      60
#      61         # Тренеруем и получаем точность для сетей
# ---> 62         train_networks(networks, dataset)
#      63
#      64         # Получаем среднюю точность для этого поколения.
#
# ~\Desktop\AAAAAAAAAA\main.py in train_networks(networks, dataset)
#      21     pbar = tqdm(total=len(networks))
#      22     for network in networks:
# ...

# %%
# %run main.py
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Desktop\AAAAAAAAAA\main.py in <module>
#     109
#     110 if __name__ == '__main__':
# --> 111     main()
#
# ~\Desktop\AAAAAAAAAA\main.py in main()
#     106                  (generations, population))
#     107
# --> 108     generate(generations, population, nn_param_choices, dataset)
#     109
#     110 if __name__ == '__main__':
#
# ~\Desktop\AAAAAAAAAA\main.py in generate(generations, population, nn_param_choices, dataset)
#      60
#      61         # Тренеруем и получаем точность для сетей
# ---> 62         train_networks(networks, dataset)
#      63
#      64         # Получаем среднюю точность для этого поколения.
#
# ~\Desktop\AAAAAAAAAA\main.py in train_networks(networks, dataset)
#      21     pbar = tqdm(total=len(networks))
#      22     for network in networks:
# ...

# %%
# %run main.py
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# ~\Desktop\AAAAAAAAAA\main.py in <module>
#     109
#     110 if __name__ == '__main__':
# --> 111     main()
#
# ~\Desktop\AAAAAAAAAA\main.py in main()
#     106                  (generations, population))
#     107
# --> 108     generate(generations, population, nn_param_choices, dataset)
#     109
#     110 if __name__ == '__main__':
#
# ~\Desktop\AAAAAAAAAA\main.py in generate(generations, population, nn_param_choices, dataset)
#      60
#      61         # Тренеруем и получаем точность для сетей
# ---> 62         train_networks(networks, dataset)
#      63
#      64         # Получаем среднюю точность для этого поколения.
#
# ~\Desktop\AAAAAAAAAA\main.py in train_networks(networks, dataset)
#      21     pbar = tqdm(total=len(networks))
#      22     for network in networks:
# ...
